# %% [markdown]
# # **GO MY CODE PROJECT.**
# # **Haberman's Cancer Survival - Exploratory Data Analysis (EDA)**
#
# ## **1. Introduction**
# Breast cancer remains one of the most prevalent cancers worldwide, making early detection and accurate prognosis critical for patient survival. This project focuses on analyzing the **Haberman's Cancer Survival** dataset, which contains historical data on breast cancer patients who underwent surgery at the University of Chicago’s Billings Hospital between **1958 and 1970**. The goal is to uncover patterns that could help predict the likelihood of a patient surviving five years or more post-surgery, thereby aiding in clinical decision-making and improving patient outcomes.
#
# ---
#
# ## **2. Business Understanding**
# Understanding survival rates after breast cancer surgery is essential for healthcare providers to optimize treatment and improve patient outcomes. Accurate predictions can assist in:
# - **Personalized Treatment Planning:** Tailoring post-operative care based on individual survival risk.
# - **Resource Allocation:** Directing medical resources and attention to high-risk patients.
# - **Improved Patient Outcomes:** Identifying critical factors affecting recovery to enhance long-term survival rates.
#
# **Objective:**
# The primary objective of this analysis is to identify the key factors influencing survival rates among breast cancer patients post-surgery. By understanding these factors, medical professionals can develop targeted treatment strategies, allocate resources more effectively, and improve overall patient care. Additionally, insights from this analysis can inform future research and support clinical decision-making.
#
# By leveraging historical patient data, this project aims to explore patterns that could guide future clinical decisions and patient counseling.
#
# ---
#
# ## **3. Objective**
# The specific goals of this exploratory data analysis are to:
# - **Explore** the dataset to uncover trends and patterns related to patient survival.
# - **Identify** the key features that influence the five-year survival rate post-surgery.
# - **Predict** survival likelihood using variables such as age, year of operation, and the number of positive axillary lymph nodes.
#
# This analysis also aims to highlight potential data biases and uncover critical medical insights, particularly regarding the role of axillary lymph nodes in survival outcomes.
#
# ---
#
# ## **4. Data Understanding**
# - **Data Source:** Haberman’s Cancer Survival Dataset (sourced from Kaggle).
#
# - **Features:**
#   - `Age`: Patient’s age at the time of surgery (numerical).
#   - `Operation Year`: Year of the surgery (numerical, representing year - 1900).
#   - `Axillary Nodes`: Number of positive axillary lymph nodes detected (numerical).
#   - `Survival Status`: Target variable indicating survival status (1 = survived 5+ years, 0 = did not survive 5 years).
#
# - **Dataset Overview:**
#   - Total records: **305 rows**
#   - Total features: **4 columns**
#   - No missing values detected.
#   - The target variable was re-coded from {1, 2} to binary {1 = survived, 0 = did not survive}.
#
# - **Initial Observations:**
#   - The majority of patients were between **30 and 83 years** old.
#   - Most surgeries took place between **1958 and 1970**.
#   - **Axillary nodes** counts varied, but most patients had fewer than **5 positive nodes**.
#
# ---
#
# ## **5. Data Preparation**
# - **Data Cleaning:**
#   - Renamed columns for clarity.
#   - Re-coded the `Survival Status` to binary values (1 = survived, 0 = did not survive).
#   - Verified data integrity and removed **19 duplicate records**.
#   - Identified outliers in features like `Age` and `Axillary Nodes`.
#
# - **Data Transformation:**
#   - Converted data types where necessary.
#   - No categorical variables were present; all features were numerical.
#   - Scaling was considered but deemed unnecessary for this exploratory analysis phase.
#
# - **Feature Engineering:**
#   - No new features were engineered at this stage.
#   - Future work may include deriving additional features (e.g., age brackets, node categories) for predictive modeling.
#
# ---
#
# ## **6. Data Analysis**
#
# ### **Univariate Analysis:**
# - **Age:** Most patients were between **40 and 60 years** old.
# - **Operation Year:** Surgeries were evenly distributed between **1958 and 1970**.
# - **Axillary Nodes:** Majority of patients had fewer than **5 positive axillary nodes**.
# - **Survival Status:** About **68%** of patients survived 5 years or longer post-surgery.
#
# ### **Bivariate Analysis:**
# - **Age vs. Survival:** Younger patients had higher survival rates.
# - **Axillary Nodes vs. Survival:** Patients with fewer positive axillary nodes had a significantly higher chance of survival.
# - **Operation Year vs. Survival:** The year of surgery had minimal impact on survival rates.
#
# ### **Visualizations:**
# - **Histograms:** Showed skewed distribution of axillary nodes, with many patients having zero positive nodes.
# - **Boxplots:** Highlighted outliers in axillary node counts among non-survivors.
# - **Heatmaps:** Revealed weak correlations between most features, except for axillary nodes, which had a notable negative correlation with survival.
#
# ### **Key Findings:**
# - **Age and axillary nodes** are significant predictors of survival.
# - Patients with **fewer positive axillary nodes** had better survival rates.
# - **Operation year** had no significant influence on survival outcomes.
# - There is a **class imbalance** in the target variable, with more patients surviving than not.
#
# ---
#
# ## **7. Conclusion**
# This analysis reveals that the **number of positive axillary nodes** is the most critical factor in predicting breast cancer survival post-surgery. Younger patients also show better survival rates, while the year of operation does not significantly affect outcomes.
#
# Key takeaways:
# - Patients with **fewer positive axillary nodes** are more likely to survive beyond five years.
# - **Age** plays a role, with younger patients generally having better outcomes.
# - There is a notable **class imbalance** in the dataset that should be addressed in predictive modeling efforts.
#
# These findings can help medical professionals focus on critical factors like lymph node involvement when planning post-operative care and follow-ups.
#
# ---
#
# ## **8. Recommendations**
#
# ### **Business-Focused Recommendations:**
# 1. **Early Detection and Screening:**
#    - Promote regular screenings, especially for women over **40 years old**, to detect cancer early and reduce the likelihood of positive axillary nodes.
#
# 2. **Targeted Post-Surgery Care:**
#    - Implement personalized post-operative care plans for patients with higher axillary node counts to improve survival chances.
#
# 3. **Patient Education:**
#    - Educate patients on the importance of **early detection** and the impact of positive axillary nodes on survival outcomes.
#
# 4. **Resource Allocation:**
#    - Allocate medical resources more efficiently by prioritizing high-risk patients (those with numerous positive axillary nodes) for intensive follow-up and monitoring.
#
#
# ### **Technical Recommendations:**
# 1. **Further Modeling:**
#    - Apply machine learning models (e.g., **Logistic Regression**, **Random Forest**, **Decision Trees**) to predict survival probabilities.
#    - Address the class imbalance using techniques like **SMOTE** or **class weighting**.
#
# 2. **Feature Scaling (if needed):**
#    - If advanced algorithms like **SVM** or **KNN** are used, apply scaling techniques such as **StandardScaler** or **MinMaxScaler**.
#
# 3. **Data Enhancement:**
#    - Incorporate more recent data reflecting modern surgical techniques and treatments.
#    - Explore adding features such as **tumor size**, **hormone receptor status**, and **genetic markers** to improve predictive power.

# %% [markdown]
# ## **1. Import the required libraries.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="whitegrid")

# %% [markdown]
#  ## **2. Loading and reading the CSV file/dataset.**

# %%
#load data
df = pd.read_csv("haberman.csv")
# Renaming the columns
df.columns=['age', 'operation_year', 'axillary_nodes', 'survival_status']
# Replacing 2s with 0s in survival status col
df[df==2] = 0

# %% [markdown]
# ## **3. Inspecting and understanding our data.**

# %%
# Check the first few rows
df.head()
# Out:
#    age  operation_year  axillary_nodes  survival_status
# 0   30              62               3                1
# 1   30              65               0                1
# 2   31              59               0                1
# 3   31              65               4                1
# 4   33              58              10                1

# %%
# Check column names and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              305 non-null    int64
#  1   operation_year   305 non-null    int64
#  2   axillary_nodes   305 non-null    int64
#  3   survival_status  305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
#To display our last five rows of the data set.
df.tail()
# Out:
#      age  operation_year  axillary_nodes  survival_status
# 300   75              62               1                1
# 301   76              67               0                1
# 302   77              65               3                1
# 303   78              65               1                0
# 304   83              58               0                0

# %%
#To display the columns of the data set.
df.columns
# Out:
# Index(['age', 'operation_year', 'axillary_nodes', 'survival_status'], dtype='object')

# %%
#To check the shape of the data set.
rows=df.shape[0]
columns=df.shape[1]
print(f"Haberman's data set has {rows} rows and {columns} columns")
# Out:
# Haberman's data set has 305 rows and 4 columns

# %%
#To check the descriptive statistics for the columns of the data set.
df.describe()
# Out:
#               age  operation_year  axillary_nodes  survival_status
# count  305.000000      305.000000      305.000000       305.000000
# mean    52.531148       62.849180        3.904918         0.734426
# std     10.744024        3.254078        7.253457         0.442364
# min     30.000000       58.000000        0.000000         0.000000
# 25%     44.000000       60.000000        0.000000         0.000000
# 50%     52.000000       63.000000        0.000000         1.000000
# 75%     61.000000       66.000000        4.000000         1.000000
# max     83.000000       69.000000       52.000000         1.000000

# %%
# Check for missing values
df.isnull().sum()
# Out:
# age                0
# operation_year     0
# axillary_nodes     0
# survival_status    0
# dtype: int64

# %%
# Check class distribution
df.value_counts()
# Out:
# age  operation_year  axillary_nodes  survival_status
# 61   59              0               1                  3
# 41   65              0               1                  2
# 50   59              0               1                  2
# 55   58              1               1                  2
# 38   60              0               1                  2
#                                                        ..
# 48   67              7               0                  1
# 49   60              1               1                  1
#      61              0               1                  1
#                      1               1                  1
# 83   58              0               0                  1
# Name: count, Length: 286, dtype: int64

# %% [markdown]
# ### **Inspecting and Understanding the Data**
#
# 1. **Loading the Dataset**
#    The dataset (`haberman.csv`) was loaded and the columns were renamed for clarity:
#    - `age`: Age of the patient at the time of operation.
#    - `op_year`: Year of operation.
#    - `axil_nodes`: Number of positive axillary nodes detected.
#    - `survived`: Survival status (1 = survived 5+ years, 0 = did not survive 5+ years).
#
# 2. **Data Cleaning**
#    - The survival column was cleaned by replacing `2` with `0` to standardize binary labels.
#
# 3. **Initial Data Exploration**
#    - Displayed the first few rows using `df.head()` to get an overview of the data structure and contents.

# %% [markdown]
# ## **4.Data Cleaning.**

# %%
# Check for missing values
df.isnull().sum()
# Out:
# age                0
# operation_year     0
# axillary_nodes     0
# survival_status    0
# dtype: int64

# %% [markdown]
# #### There are no missing values in the data set.

# %%
# Recode 'survived' (1 = survived, 0 = not survived)
df['survival_status'] = df['survival_status'].map({1: 1, 2: 0})

# %%
# Check for duplicates
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 19

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
# Display class distribution
print("Survival Staus Distribution:\n", df['survival_status'].value_counts())
# Out:
# Survival Staus Distribution:
#  survival_status
# 1.0    207
# Name: count, dtype: int64

# %%
# Check for all the numerical columns 
numerical_columns = df.select_dtypes(include=['number']).columns
print(f"The numerical columns include: {numerical_columns}")
# Out:
# The numerical columns include: Index(['age', 'operation_year', 'axillary_nodes', 'survival_status'], dtype='object')

# %%
# Check for the categorical columns
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

# Conditional check and print
if len(categorical_columns) > 0:
    print(f"The categorical columns include: {list(categorical_columns)}")
else:
    print("There are no categorical columns.")
# Out:
# There are no categorical columns.

# %% [markdown]
# #### Since the data type is integer, basically numerical, we are going to check for outliers.
# * Check for outliers using the following methods:Visualizations (box plots) or the IQR method.
# * Then treat outliers through: cap, remove, or adjust.

# %%
# List of numerical columns in the dataset
numerical_columns = ['age', 'operation_year', 'axillary_nodes', 'survival_status']

# Defining a function to check and count outliers using the IQR method
def check_outliers_iqr(df, numerical_columns):
    outliers_count = {}
    for column in numerical_columns:
        # Calculate Q1 (25th percentile), Q3 (75th percentile), and IQR
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        
        # Calculate lower and upper bounds
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        # Identify and count outliers
        outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
        outliers_count[column] = len(outliers)  # Store outliers count for each column
    
    return outliers_count

# Get the count of outliers in each numerical column
outliers_count = check_outliers_iqr(df, numerical_columns)

# Print the outliers count for each column
for column, count in outliers_count.items():
    print(f"Outliers in '{column}': {count}")
# Out:
# Outliers in 'age': 0
# Outliers in 'operation_year': 0
# Outliers in 'axillary_nodes': 34
# Outliers in 'survival_status': 0

# %% [markdown]
# ### 📊 **Outlier Analysis**
#
# The dataset was analyzed to detect outliers across all numerical features using standard statistical techniques (e.g., IQR method or boxplots). The following observations were made:
#
# - **`age`** 🧑‍⚕️
#   - **Outliers Detected:** `0`
#   - **Interpretation:** The age distribution appears to be within a normal range, indicating that no patients had extreme ages that could be considered outliers.
#
# - **`operation_year`** 📅
#   - **Outliers Detected:** `0`
#   - **Interpretation:** All operation years fall within the expected range (1958 to 1970), with no anomalies or out-of-range values detected.
#
# - **`axillary_nodes`** 🦠
#   - **Outliers Detected:** `34`
#   - **Interpretation:** A significant number of outliers were detected in the **axillary lymph node** count. This suggests that some patients had an unusually high number of positive lymph nodes, which could be critical for survival analysis. These outliers might represent severe cases or data anomalies that require further investigation.
#
# - **`survival_status`** ❤️
#   - **Outliers Detected:** `0`
#   - **Interpretation:** Since this is a binary variable (1 = Survived, 0 = Not Survived), outliers are not applicable or expected.
#
#
# ### ⚖ **Key Considerations:**
# - The **outliers in `axil_nodes`** could significantly impact model performance and interpretation.

# %% [markdown]
# ## **Outlier Visualization.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create box plots for each numerical column
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(4, 4, i) 
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot for {column}')
plt.tight_layout()
plt.show()

# %%
# Boxplot for axil_nodes
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['axillary_nodes'])
plt.title('Boxplot of Axillary Nodes')
plt.show()

# Histogram for distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['axillary_nodes'], bins=30, kde=True)
plt.title('Distribution of Axillary Nodes')
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## **Handle the outliers in the numerical columns using capping or winsorization.**

# %%
# Cap values at 5th and 95th percentiles
lower_cap = df['axillary_nodes'].quantile(0.05)
upper_cap = df['axillary_nodes'].quantile(0.95)

df_capped = df.copy()
df_capped['axillary_nodes'] = df_capped['axillary_nodes'].clip(lower=lower_cap, upper=upper_cap)

# Check capped distribution
sns.boxplot(x=df_capped['axillary_nodes'])
plt.title('Boxplot after Capping')
plt.show()

# %% [markdown]
# ### **Remove Whitespace from Column Names**

# %%
# Strip leading and trailing whitespaces from column names
df.columns = df.columns.str.strip()

# Verify cleaned column names
print(df.columns.tolist())
# Out:
# ['age', 'operation_year', 'axillary_nodes', 'survival_status']

# %% [markdown]
# ### **Handle Whitespace in Numerical Columns**

# %%
# Convert numerical columns read as strings to proper numeric types
df = df.apply(lambda col: pd.to_numeric(col, errors='ignore'))

# Check data types after conversion
print(df.dtypes)
# Out:
# age                  int64
# operation_year       int64
# axillary_nodes       int64
# survival_status    float64
# dtype: object

# %% [markdown]
# ## **5. Exploratory Data Analysis(EDA)**

# %% [markdown]
# ### We will focus on:
# * Univariate analysis.
# * Bivariate analysis.
# * Multivariate analysis.

# %% [markdown]
# ### **5.1 Univariate Analysis.**

# %% [markdown]
# 📊 **Distributions of Age, Operation Year, Axillary Nodes, and Survival Status**

# %%
# Plotting distributions for numerical features
num_cols = ['age', 'operation_year', 'axillary_nodes']

for col in num_cols:
    plt.figure(figsize=(8,4))
    sns.histplot(df[col], kde=True, bins=20)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# Plot survived distribution
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='survival_status')
plt.title("Survival Status Distribution")
plt.xlabel("Survived (1) / Not Survived (0)")
plt.ylabel("Count")
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### **5.2 Bivariate Analysis.**

# %% [markdown]
# 📊 **Feature Comparisons and Relationships with Survival Status**

# %%
# Boxplots to compare features with survival status
for col in num_cols:
    plt.figure(figsize=(8,4))
    sns.boxplot(x='survival_status', y=col, data=df)
    plt.title(f"{col} vs Survival Status")
    plt.xlabel("Survived (1) / Not Survived (0)")
    plt.ylabel(col)
    plt.show()

# Pairplot for feature relationships
sns.pairplot(df, hue='survival_status', diag_kind='kde')
plt.suptitle("Pairplot of Features", y=1.02)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### **5.3 Multivariate Analysis.**

# %% [markdown]
# 📈 **Survival Trends Over the Years: Tracking Cancer Patient Outcomes**

# %%
# Step 1: Handle missing or infinite values in 'survival_status'
df['survival_status'] = pd.to_numeric(df['survival_status'], errors='coerce')  # Coerce non-numeric to NaN
df['survival_status'] = df['survival_status'].fillna(-1)  # Fill NaN with -1 (or choose an appropriate placeholder)
df['survival_status'] = df['survival_status'].astype(int)  # Now safely convert to int

# Step 2: Group by 'operation_year' for survival counts
count_of_survival = df.groupby('operation_year')['survival_status'].value_counts().unstack().fillna(0)

# Debugging: Check data structure
print(count_of_survival.head())
print(count_of_survival.columns)

# Step 3: Plotting survival trends
plt.figure(figsize=(14, 8))

# Plot for patients who survived 5+ years
plt.plot(count_of_survival.index, count_of_survival.get(1, pd.Series(0, index=count_of_survival.index)), 
         label='Survived 5+ Years', marker='o')

# Plot for patients who did not survive 5 years
plt.plot(count_of_survival.index, count_of_survival.get(0, pd.Series(0, index=count_of_survival.index)), 
         label='Did Not Survive 5 Years', marker='o')

# Adding labels and title
plt.xlabel('Year of Operation')
plt.ylabel('Count')
plt.title('Survival Trends by Year of Operation')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# survival_status  -1   1
# operation_year
# 58               11  22
# 59                9  15
# 60                4  22
# 61                3  21
# 62                7  15
# Index([-1, 1], dtype='int32', name='survival_status')

# %%
df['survival_status'] = pd.to_numeric(df['survival_status'], errors='coerce')
df.dropna(subset=['survival_status'], inplace=True)
df['survival_status'] = df['survival_status'].astype(int)

# %% [markdown]
# 📊 Trends in Cancer Survival, Axillary Nodes, and Age by Year

# %%
# Plot for patients who survived 5+ years
plt.plot(count_of_survival.index, 
         count_of_survival.get(1, pd.Series(0, index=count_of_survival.index)), 
         label='Survived 5+ Years', marker='o')

# Plot for patients who did not survive 5 years (handling missing key with .get())
plt.plot(count_of_survival.index, 
         count_of_survival.get(0, pd.Series(0, index=count_of_survival.index)), 
         label='Did Not Survive 5 Years', marker='o')

# Optional: Also plot entries with survival status -1 if relevant
if -1 in count_of_survival.columns:
    plt.plot(count_of_survival.index, 
             count_of_survival[-1], 
             label='Unknown Survival Status (-1)', marker='o', linestyle='--')

# Continue with the rest of your plotting code...
plt.xlabel('Year of Operation')
plt.ylabel('Count / Average')
plt.title('Trends in Cancer Survival by Year')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **5.4 Correlation Analysis.**

# %% [markdown]
# 🔗 **Correlation Matrix: Exploring Feature Relationships**

# %%
# Correlation matrix
corr_matrix = df.corr()

# Heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
